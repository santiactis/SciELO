# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette("Blues_r", 10))

df = pd.read_excel('G:\python\gui\country.xls', header=0)

# %%
#df.head(10)

# %%
#df.info()

# %%
df[[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]] = df[[2011, 2012, 2013, 2014, 2015, 
                                                                           2016, 2017, 2018]].fillna(0)

# %%
df = df.astype({2011:'int32', 2012:'int32', 2013:'int32', 2014:'int32', 2015:'int32', 2016:'int32', 2017:'int32'
           , 2018:'int32'})

# %%
#df.head(10)

# %%
#df.tail(10)

# %%
#df.describe()

# %%
df.groupby('Cited document type')

# %%
#df.head(10)

# %%
df_melt = pd.melt(df, id_vars=['Affiliation country','Cited document type'], value_vars=[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], var_name='Year', value_name='Quantity')
df_melt.groupby('Year').head(15)
# Out:
#      Affiliation country Cited document type  Year  Quantity
# 0            Afghanistan               other  2011         0
# 1            Afghanistan             journal  2011         0
# 2      Afghanistan Total                 NaN  2011         0
# 3                Albania             journal  2011        19
# 4                Albania               other  2011         3
# ...                  ...                 ...   ...       ...
# 6849             Algeria               other  2018       232
# 6850             Algeria                book  2018       128
# 6851             Algeria         proceedings  2018        25
# 6852             Algeria              thesis  2018         3
# 6853       Algeria Total                 NaN  2018      1413
#
# [120 rows x 4 columns]

# %%
#df['Cited document type'].unique()

# %%
df_other = df[df['Cited document type'] == 'other']
df_other.drop('Cited document type', axis=1, inplace=True)
df_other = df_other.reset_index(drop=True)

df_book = df[df['Cited document type'] == 'book']
df_book.drop('Cited document type', axis=1, inplace=True)
df_book = df_book.reset_index(drop=True)

df_journal = df[df['Cited document type'] == 'journal']
df_journal.drop('Cited document type', axis=1, inplace=True)
df_journal = df_journal.reset_index(drop=True)

df_proceedings = df[df['Cited document type'] == 'proceedings']
df_proceedings.drop('Cited document type', axis=1, inplace=True)
df_proceedings = df_proceedings.reset_index(drop=True)

df_thesis = df[df['Cited document type'] == 'thesis']
df_thesis.drop('Cited document type', axis=1, inplace=True)
df_thesis = df_thesis.reset_index(drop=True)
# Out:
# G:\Anaconda\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_other_top_2011 = df_other.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_other_top_2012 = df_other.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_other_top_2013 = df_other.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_other_top_2014 = df_other.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_other_top_2015 = df_other.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_other_top_2016 = df_other.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_other_top_2017 = df_other.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_other_top_2018 = df_other.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
df_book_top_2011 = df_book.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_book_top_2012 = df_book.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_book_top_2013 = df_book.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_book_top_2014 = df_book.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_book_top_2015 = df_book.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_book_top_2016 = df_book.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_book_top_2017 = df_book.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_book_top_2018 = df_book.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
df_proceedings_top_2011 = df_proceedings.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_proceedings_top_2012 = df_proceedings.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_proceedings_top_2013 = df_proceedings.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_proceedings_top_2014 = df_proceedings.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_proceedings_top_2015 = df_proceedings.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_proceedings_top_2016 = df_proceedings.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_proceedings_top_2017 = df_proceedings.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_proceedings_top_2018 = df_proceedings.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
df_journal_top_2011 = df_journal.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_journal_top_2012 = df_journal.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_journal_top_2013 = df_journal.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_journal_top_2014 = df_journal.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_journal_top_2015 = df_journal.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_journal_top_2016 = df_journal.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_journal_top_2017 = df_journal.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_journal_top_2018 = df_journal.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
df_thesis_top_2011 = df_thesis.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_thesis_top_2012 = df_thesis.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_thesis_top_2013 = df_thesis.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_thesis_top_2014 = df_thesis.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_thesis_top_2015 = df_thesis.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_thesis_top_2016 = df_thesis.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_thesis_top_2017 = df_thesis.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_thesis_top_2018 = df_thesis.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
df_total = df[df['Affiliation country'].str.contains("Total")]
df_total.drop(['Cited document type'], axis=1, inplace=True)
df_total = df_total.reset_index(drop=True)
df_total_top_2011 = df_total.nlargest(10, 2011, keep="all").reset_index(drop=True)
df_total_top_2012 = df_total.nlargest(10, 2012, keep="all").reset_index(drop=True)
df_total_top_2013 = df_total.nlargest(10, 2013, keep="all").reset_index(drop=True)
df_total_top_2014 = df_total.nlargest(10, 2014, keep="all").reset_index(drop=True)
df_total_top_2015 = df_total.nlargest(10, 2015, keep="all").reset_index(drop=True)
df_total_top_2016 = df_total.nlargest(10, 2016, keep="all").reset_index(drop=True)
df_total_top_2017 = df_total.nlargest(10, 2017, keep="all").reset_index(drop=True)
df_total_top_2018 = df_total.nlargest(10, 2018, keep="all").reset_index(drop=True)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_other_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises en citas en tipo de publicación "Otros" \n para el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_book_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises en citas en tipo de publicación "Book" \n para el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_proceedings_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises en citas en tipo de publicación "Proceedings" \n para el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_journal_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises en citas en tipo de publicación "Journal" \n para el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_thesis_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises en citas en tipo de publicación "Thesis" \n para el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)

# %%
plt.figure(figsize=(15,8))
f = sns.barplot(x='Affiliation country', y=2011, data=df_total_top_2011)
f.set_ylabel('Cantidad', fontsize=17)
f.set_xlabel('País', fontsize=17)
f.set_title('Top 10 de paises para citas en todos los tipos de artículos \n en el año 2011', fontsize=20)
f.set_xticklabels(f.get_xticklabels(),rotation=45, fontsize=15)
f.tick_params(axis='y', labelsize=15)

for p in f.patches:
        f.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=15)
